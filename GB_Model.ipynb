# %%
#import key packages
import pandas as pd
import numpy as np

# %%
ready_games = pd.read_csv('Game_Data.csv').drop(columns = 'Unnamed: 0') # read in the training data

# %%
# gather all potential parameteres
all_preds = ['Home Name',
 'Home W',
 'Home L',
 'Home SV',
 'Home G',
 'Home GS',
 'Home IP',
 'Home K/9',
 'Home BB/9',
 'Home HR/9',
 'Home BABIP',
 'Home LOB%',
 'Home GB%',
 'Home HR/FB',
 'Home ERA',
 'Home xERA',
 'Home FIP',
 'Home xFIP',
 'Home WAR',
 'Away Name',
 'Away W',
 'Away L',
 'Away SV',
 'Away G',
 'Away GS',
 'Away IP',
 'Away K/9',
 'Away BB/9',
 'Away HR/9',
 'Away BABIP',
 'Away LOB%',
 'Away GB%',
 'Away HR/FB',
 'Away ERA',
 'Away xERA',
 'Away FIP',
 'Away xFIP',
 'Away WAR',
 'Home AB',
 'Home R',
 'Home H',
 'Home 2B',
 'Home 3B',
 'Home HR',
 'Home RBI',
 'Home TB',
 'Home BB',
 'Home SO',
 'Home SB',
 'Home AVG',
 'Home OBP',
 'Home SLG',
 'Home OPS',
 'Home Field E',
 'Home Field FP',
 'Home Field TC',
 'Home Field PO',
 'Home Field A',
 'Home Pit_Br #P',
 'Home Pit_Br PAge',
 'Home Pit_Br RA/G',
 'Home Pit_Br W',
 'Home Pit_Br L',
 'Home Pit_Br W-L%',
 'Home Pit_Br ERA',
 'Home Pit_Br G',
 'Home Pit_Br GS',
 'Home Pit_Br GF',
 'Home Pit_Br CG',
 'Home Pit_Br tSho',
 'Home Pit_Br cSho',
 'Home Pit_Br SV',
 'Home Pit_Br IP',
 'Home Pit_Br H',
 'Home Pit_Br R',
 'Home Pit_Br ER',
 'Home Pit_Br HR',
 'Home Pit_Br BB',
 'Home Pit_Br IBB',
 'Home Pit_Br SO',
 'Home Pit_Br HBP',
 'Home Pit_Br BK',
 'Home Pit_Br WP',
 'Home Pit_Br BF',
 'Home Pit_Br ERA+',
 'Home Pit_Br FIP',
 'Home Pit_Br WHIP',
 'Home Pit_Br H9',
 'Home Pit_Br HR9',
 'Home Pit_Br BB9',
 'Home Pit_Br SO9',
 'Home Pit_Br SO/W',
 'Home Pit_Br LOB',
 'Home Hit_Saber R/G',
 'Home Hit_Saber Outs',
 'Home Hit_Saber RC',
 'Home Hit_Saber RC/G',
 'Home Hit_Saber AIR',
 'Home Hit_Saber BAbip',
 'Home Hit_Saber BA',
 'Home Hit_Saber lgBA',
 'Home Hit_Saber OBP',
 'Home Hit_Saber lgOBP',
 'Home Hit_Saber SLG',
 'Home Hit_Saber lgSLG',
 'Home Hit_Saber OPS',
 'Home Hit_Saber lgOPS',
 'Home Hit_Saber OPS+',
 'Home Hit_Saber OWn%',
 'Home Hit_Saber BtRuns',
 'Home Hit_Saber BtWins',
 'Home Hit_Saber TotA',
 'Home Hit_Saber SecA',
 'Home Hit_Saber ISO',
 'Home Hit_Saber PwrSpd',
 'Home Pit_Prob RA/G',
 'Home Pit_Prob PtchR',
 'Home Pit_Prob PtchW',
 'Home Pit_Prob Plays',
 'Home Pit_Prob WPA',
 'Home Pit_Prob WPA+',
 'Home Pit_Prob WPA-',
 'Home Pit_Prob aLI',
 'Home Pit_Prob WPA/LI',
 'Home Pit_Prob Clutch',
 'Home Pit_Prob cWPA',
 'Home Pit_Prob cWPA+',
 'Home Pit_Prob cWPA-',
 'Home Pit_Prob acLI',
 'Home Pit_Prob cClutch',
 'Home Pit_Prob RE24',
 'Home Pit_Prob REW',
 'Home Pit_Prob boLI',
 'Home Pit_Prob RE24/boLI',
 'Home Pit_Prob LevHi',
 'Home Pit_Prob LevMd',
 'Home Pit_Prob LevLo',
 'Away AB',
 'Away R',
 'Away H',
 'Away 2B',
 'Away 3B',
 'Away HR',
 'Away RBI',
 'Away TB',
 'Away BB',
 'Away SO',
 'Away SB',
 'Away AVG',
 'Away OBP',
 'Away SLG',
 'Away OPS',
 'Away Field E',
 'Away Field FP',
 'Away Field TC',
 'Away Field PO',
 'Away Field A',
 'Away Pit_Br #P',
 'Away Pit_Br PAge',
 'Away Pit_Br RA/G',
 'Away Pit_Br W',
 'Away Pit_Br L',
 'Away Pit_Br W-L%',
 'Away Pit_Br ERA',
 'Away Pit_Br G',
 'Away Pit_Br GS',
 'Away Pit_Br GF',
 'Away Pit_Br CG',
 'Away Pit_Br tSho',
 'Away Pit_Br cSho',
 'Away Pit_Br SV',
 'Away Pit_Br IP',
 'Away Pit_Br H',
 'Away Pit_Br R',
 'Away Pit_Br ER',
 'Away Pit_Br HR',
 'Away Pit_Br BB',
 'Away Pit_Br IBB',
 'Away Pit_Br SO',
 'Away Pit_Br HBP',
 'Away Pit_Br BK',
 'Away Pit_Br WP',
 'Away Pit_Br BF',
 'Away Pit_Br ERA+',
 'Away Pit_Br FIP',
 'Away Pit_Br WHIP',
 'Away Pit_Br H9',
 'Away Pit_Br HR9',
 'Away Pit_Br BB9',
 'Away Pit_Br SO9',
 'Away Pit_Br SO/W',
 'Away Pit_Br LOB',
 'Away Hit_Saber R/G',
 'Away Hit_Saber Outs',
 'Away Hit_Saber RC',
 'Away Hit_Saber RC/G',
 'Away Hit_Saber AIR',
 'Away Hit_Saber BAbip',
 'Away Hit_Saber BA',
 'Away Hit_Saber lgBA',
 'Away Hit_Saber OBP',
 'Away Hit_Saber lgOBP',
 'Away Hit_Saber SLG',
 'Away Hit_Saber lgSLG',
 'Away Hit_Saber OPS',
 'Away Hit_Saber lgOPS',
 'Away Hit_Saber OPS+',
 'Away Hit_Saber OWn%',
 'Away Hit_Saber BtRuns',
 'Away Hit_Saber BtWins',
 'Away Hit_Saber TotA',
 'Away Hit_Saber SecA',
 'Away Hit_Saber ISO',
 'Away Hit_Saber PwrSpd',
 'Away Pit_Prob RA/G',
 'Away Pit_Prob PtchR',
 'Away Pit_Prob PtchW',
 'Away Pit_Prob Plays',
 'Away Pit_Prob WPA',
 'Away Pit_Prob WPA+',
 'Away Pit_Prob WPA-',
 'Away Pit_Prob aLI',
 'Away Pit_Prob WPA/LI',
 'Away Pit_Prob Clutch',
 'Away Pit_Prob cWPA',
 'Away Pit_Prob cWPA+',
 'Away Pit_Prob cWPA-',
 'Away Pit_Prob acLI',
 'Away Pit_Prob cClutch',
 'Away Pit_Prob RE24',
 'Away Pit_Prob REW',
 'Away Pit_Prob boLI',
 'Away Pit_Prob RE24/boLI',
 'Away Pit_Prob LevHi',
 'Away Pit_Prob LevMd',
 'Away Pit_Prob LevLo',
 'Target']

# %%
# Measure the correlation of each value to the target 
corr_vals = pd.DataFrame(np.abs(ready_games[all_preds].corr()['Target'])).sort_values(by = 'Target')
corr_vals['index'] = np.arange(0,len(corr_vals))
corr_vals.head()

# %%
# Remove all but the top 20% most correlated parameters
kept = corr_vals.loc[corr_vals['index'] > 4 * len(corr_vals) / 5]

# %%
# create a list of all of the selected parameters 
important_preds = list(kept.T.columns)[0:len(kept) - 1]

# %%
# create the training and testing data for the model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
X = ready_games[important_preds]
y = ready_games['Target']
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=.25)

# %%
# Tune the model to find the most accurate parameters
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 4500, stop = 5500, num = 21)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [1,2,3]

learning_rate = [x for x in np.linspace(start = 0.0009, stop = .0015, num = 26)]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
              'learning_rate': learning_rate}

 # Use the random grid to search for best hyperparameters
# create the base model to tune
gb_base = GradientBoostingClassifier()
# Random search of parameters, using 4 fold cross validation
gb_random = RandomizedSearchCV(estimator = gb_base, param_distributions = random_grid, n_iter = 500, cv = 3, verbose=2, random_state=42, n_jobs = 8)
# Fit the random search model
gb_random.fit(X_train, y_train)
print(gb_random.best_params_)
# save the optimal parameters
best_params = gb_random.best_params_

# %%
# create a RandomForest model using the selected parameters
gb = GradientBoostingClassifier(n_estimators=best_params['n_estimators'], max_features = best_params['max_features'], 
                              max_depth = best_params['max_depth'])

# %%
# Measure the improvement gained from tuning the model, compared to a base model
from sklearn.metrics import accuracy_score
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    accuracy = 100 * accuracy_score(predictions,test_labels)
    print('Model Performance')
    print('Accuracy = {:0.3f}%.'.format(accuracy))
    
    return accuracy
base_model = GradientBoostingClassifier()
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)

gb.fit(X_train, y_train)
random_accuracy = evaluate(gb, X_test, y_test)
print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - base_accuracy) / base_accuracy))

# %%
# Save the model
import joblib
filename = 'finalized_GB.sav'
joblib.dump(gb, filename)

# %%
# Save the selected parameters
kept.T.to_csv('Params.csv')
